# %% [markdown]
# <a href="https://colab.research.google.com/github/EricLu123/YOLOv11_MM_Detection/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#make sure you have access to the gpu
# !nvidia-smi
# Out:
# Sun Aug  2 09:04:14 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   37C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# Install YOLO11 via Ultralytics
# %pip install "ultralytics<=8.3.40" supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA L4, 22563MiB)
# Setup complete ✅ (12 CPUs, 53.0 GB RAM, 47.0/235.7 GB disk)

# %%
# %cd /content

# YOLO11training
# !yolo task=detect mode=train model=yolo11n.pt data=/content/drive/MyDrive/mmds_split_dataset/data.yaml epochs=100 batch=8 imgsz=1024 plots=True project=/content/drive/MyDrive/mmds_train_result
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.4.115 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/mmds_train_result/train47/weights/best.pt data=/content/drive/MyDrive/mmds_split_dataset/data.yaml
# Out:
# Ultralytics 8.3.40 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (NVIDIA L4, 22563MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 90.5MB/s]
# val: Scanning /content/drive/MyDrive/mmds_split_dataset/valid/labels.cache... 76 images, 0 backgrounds, 0 corrupt: 100% 76/76 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:19<00:00,  3.88s/it]
#                    all         76        238      0.768      0.937      0.905      0.813
# Speed: 5.9ms preprocess, 18.9ms inference, 0.0ms loss, 9.5ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
from roboflow import Roboflow

ROBOFLOW_API_KEY = "OXB7z5t00nHllKLD8ggP" # Your actual Roboflow API key
rf_client = Roboflow(api_key=ROBOFLOW_API_KEY)

project = rf_client.workspace("yolo-v7-balaa").project("yolov11-mm-tumor-cells")
version = project.version(3)
version.deploy(model_type="yolov11",model_path="/content/drive/MyDrive/mmds_train_result/train47/")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# View the status of your deployment at: https://app.roboflow.com/yolo-v7-balaa/yolov11-mm-tumor-cells/3
# Share your model with the world at: https://universe.roboflow.com/yolo-v7-balaa/yolov11-mm-tumor-cells/model/3
